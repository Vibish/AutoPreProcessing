# %%
import pandas as pd
from AutoPreProcessing import EDA

# %%
df = pd.read_csv('AutoPreProcessing/data/DeathRate.csv')

# %%
pd.DataFrame(round((df.isnull().sum()/df.shape[0])*100)).reset_index().rename(columns={'index': 'Feature',0:'NullPercentage'})
# Out:
#                            Feature  NullPercentage
# 0                       Unnamed: 0             0.0
# 1                             Year             0.0
# 2                             Race             0.0
# 3                              Sex             2.0
# 4  Average Life Expectancy (Years)             3.0
# 5          Age-adjusted Death Rate            22.0
# 6                   LifeExpectency             0.0
# 7                            Race2             2.0

# %%
CategoricalFeatures = ['Sex','LifeExpectency','Race','Race2']
eda = EDA(df,CategoricalFeatures,title='Testing the Package')
eda.EDAToHTML()
# Out:
# CorrList 0.0
# ListOfFields 0.0
# CategoricalVsContinuous 0.0
# CategoriesCount 0.01200246810913086
# ChiSquareOfDFCols 0.003987550735473633
# ChiSquareOfDFCols 0.0
# ChiSquareOfDFCols 0.003999471664428711
# ChiSquareOfDFCols 0.0015032291412353516
# UpdateChiSq 0.0
# ChiSquareOfDFCols 0.0010008811950683594
# UpdateChiSq 0.0
# ChiSquareOfDFCols 0.0
# UpdateChiSq 0.0
# ChiSquareOfDFCols 0.0
# UpdateChiSq 0.0
# WOEList 0.06402349472045898
# HistChart 0.003999948501586914
# BoxPlot 0.06351566314697266
# HistChart 0.0029840469360351562
# c:\python36\lib\site-packages\pandas\core\series.py:696: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self.loc[key]
# BoxPlot 0.056499481201171875
# ContinuousSummary 0.13203716278076172
# Anova 0.024013757705688477
# VIF 0.006002902984619141
# std_variance 0.0015192031860351562
# c:\python36\lib\site-packages\scipy\stats\stats.py:2916: RuntimeWarning: invalid value encountered in double_scalars
#   ssbn += _square_of_sums(a - offset) / float(len(a))
# ScatterPlot 2.323803424835205
# 'C:\\Users\\kunjithapath\\Desktop\\AutoPreProcessing\\AutoPreProcessing\\HTMLTemplate\\dist\\result.html'

# %%
import seaborn as sns
sns.set(style="ticks")

sns.pairplot(df.dropna(),kind="reg", plot_kws={'line_kws':{'color':'orange'}})
